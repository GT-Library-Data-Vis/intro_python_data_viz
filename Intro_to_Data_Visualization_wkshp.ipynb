# %%
# Welcome to Introduction to Data Visualization in Python
# Raven Davis
# raven.davis@library.gatech.edu

# Resources
# GT Library: www.library.gatech.edu -> ebooks, O'Reilly Database
# Anaconda Distribution: www.anaconda.com
# Datacamp:  www.datacamp.com
# LinkedIn Learning: https://linkedinlearning.gatech.edu/


# Objectives
# Learn basics of visualization using Matplotlib
# Create data visualizations using Pandas, Matplotlib, and Seaborn data visualization libraries

# %%
# Why Python?
# --- Popular language for data analysis, data science, and general programming
# --- Helps to create reproducible workflows to make research and analysis more efficient (modularize code, big data, etc.)

# Why Colab?
# --- Colab is cloud-based python notebook
# --- Don't have to install any software
# --- Can easily collaborate and ensure everyone has same version

# %%
# Colab navigation

# Comments use pound sign

# '+Code' to add code cell

# Play button to run code

# '+ Text' adds markdown cell

# 'Ctrl + /' to comment or un-comment multiple lines

# %%
# Matplotlib is a Python package that is widely used throughout the scientific Python community to create high-quality and publication-ready graphics.
# It supports a wide range of raster and vector graphics formats including PNG, PostScript, EPS, PDF and SVG.

# Matplotlib is the actual engine behind the plotting capabilities of both Pandas and plotnine packages.
# For example, when we call the .plot method on Pandas data objects, we actually use the matplotlib package.

# https://matplotlib.org/stable/gallery/

# %%
# Importing Numpy
import numpy as np # numerical and scientific computing library

# Importing Pandas
import pandas as pd # used for data analysis and data wrangling

# Importing Matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt # most popular data visualization library

# Importing seaborn
import seaborn as sns # data visualization library built on matplotlib

# %%
# Import data for plot
data = pd.read_csv("/content/maternal_health_clean.csv")

data.head() # view first few rows of data
# Out:
#             county  broadband_access_pct  \
# 0    Lanier County                  85.1
# 1     Bryan County                  95.1
# 2   Appling County                  50.9
# 3     Rabun County                  90.3
# 4  Bleckley County                  55.1
#
#    births_mothers_less_12yrs_education_pct  low_birthweight_births_pct  \
# 0                                     13.2                        10.1
# 1                                      5.4                         7.6
# 2                                     22.8                         9.3
# 3                                     17.5                         7.8
# 4                                     14.0                         9.4
#
#    premature_births_pct  births_teens_pct  maternal_death  \
# 0                  12.6               7.4               0
# 1                   9.0               3.8               0
# 2                  11.8              12.7               1
# ...

# %%
# Variables in dataset
# county -> county names
# broadband_access_pct ->  Percentage of population with access to fixed terrestrial broadband service at 100/20 Mbps or higher advertised speeds.
# births_mothers_less_12yrs_education_pct -> percentage of births to mothers with less than 12 years of education from 2015-2019
# low_birthweight_births_pct -> Estimated percentage of live births that are low birth weight (less than 2,500 grams).
# premature_births_pct -> Estimated percentage of live births that are preterm (before 37 weeks).
# births_teens_pct -> percentage of births to teens ages 15-19, from 2015-2019
# maternal_death -> Counties reporting maternal deaths (up to 42 days postpartum) or no maternal deaths.
# county_categorization -> Classifications of counties based on broadband access and maternal health risk.
#  The “Double Burden” category represents counties that face both poor broadband access and high maternal health risks.
# The “Opportunity” category highlights counties where existing broadband infrastructure could be leveraged to improve health outcomes.
# The “Single Burden” category includes counties with lower maternal health risks or lower connectivity challenges.
# The “Milestone” category identifies counties that meet certain broadband milestones and health benchmarks.
# maternity_care_deserts_value -> Access to obstetric care in a given county from none (desert) to full. Maternity care deserts are counties
# without a hospital, birth center, or provider offering obstetric care.
# Maternity care deserts are counties without a hospital, birth center, or provider offering obstetric care.
# Counties were classified as having low access to maternity care services if there was one or less hospital offering OB service and
# fewer than 60 OB providers per 10,000 births, and the proportion of women without health insurance was 10 percent or greater.
# Counties were classified as having moderate access to maternity care services if there was one or less hospital offering OB service and
# fewer than 60 OB providers per 10,000 births, and the proportion of women without health insurance was less than 10 percent. Counties with
# full access had either two or more hospitals offering OB services or 60 or more OB providers per 10,000 births.

# %%
# Key things to consider when visualizing data

# What type of data are you working with?

# Time series - data points collected over an interval of time and indexed by time.
# Quantitative/Numerical - data with numerical values, either discrete or continuous
# Qualitative/Categorical - data that can be split into categories
# Geographic/Spatial - data tied to a location on earth.

# What question are you attempting to answer?

# Comparison - Do you want to compare different categories/groups?
# Trend - Do you want to illustrate trends, increases or decreases in a value over time?
# Composition - Do you want to compare the different parts of a whole?
# Distribution - Do you want to see the frequency of values within a variable
# Relationship - Do you want to see the relationship/correlation between variables?

# %%
# Exploratory data analysis

data.describe()
# Out:
#        broadband_access_pct  births_mothers_less_12yrs_education_pct  \
# count            159.000000                               159.000000
# mean              74.264151                                16.633962
# std               25.635483                                 5.959991
# min                0.000000                                 3.900000
# 25%               60.700000                                12.600000
# 50%               82.100000                                16.700000
# 75%               95.150000                                19.650000
# max              100.000000                                32.600000
#
#        low_birthweight_births_pct  premature_births_pct  births_teens_pct  \
# count                  159.000000            159.000000        159.000000
# mean                    10.181132             11.813208          8.277987
# std                      2.239128              1.797893          2.567978
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   county                                   159 non-null    object
#  1   broadband_access_pct                     159 non-null    float64
#  2   births_mothers_less_12yrs_education_pct  159 non-null    float64
#  3   low_birthweight_births_pct               159 non-null    float64
#  4   premature_births_pct                     159 non-null    float64
#  5   births_teens_pct                         159 non-null    float64
#  6   maternal_death                           159 non-null    int64
#  7   county_categorization                    159 non-null    object
#  8   maternity_care_deserts_value             159 non-null    object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 11.3+ KB

# %%
# What kind of plots might be most appropriate for this data?

# Columns with categorical data: county, county_categorization, maternity_care_deserts_value, maternal death (binary value)

# Columns with numerical data: broadband_access_pct, births_mothers_less_12yrs_education_pct, low_birthweight_births_pct,
# premature_births_pct, births_teens_pct

# %%
# Two methods for creating plots with Matplotlib

# PyPlot API - charts are created with plot() function and then customized with additional functions. Can plot using Pandas using this API

# Object-oriented - charts are creating by creating a plot "object" and then customized using figure and axis methods/functions. Allows for more customization than API method.

# %%
# PyPlot API Plotting

data.groupby("county_categorization")["broadband_access_pct"].mean() # use the groupby function to get average broadband percentage for each county categorization
# Out:
# county_categorization
# Double Burden    62.932258
# Milestone        95.580769
# Opportunity      96.668571
# Single Burden    59.531343
# Name: broadband_access_pct, dtype: float64

# %%
# Charts to look at the distribution of values

# %%
# Boxplots

## Boxplots are used to show the distribution of a variable using five summary statistics. The box extends from the 1st quartile to the third quartile (25th and 75th quantiles)
## and the line within the box represents the median. The "whiskers" show the range of the data, with dots representing outliers.
## One axis should be categorical, and the other numerical


## Create boxplot for entire dataset
# data.boxplot(by="county_categorization") # one boxplot is created for each value of the column specified in "by"

## Create boxplot for specific column
# data.boxplot(column = "broadband_access_pct", by= "county_categorization")

# Change boxplot color using boxprops for the boxes, medianprops for the median line, whiskerprops for the whiskers, and flierprops for the outliers
# data.boxplot(column = "broadband_access_pct", by= "county_categorization", boxprops = dict(color = "red"), medianprops = dict(color="red"),
#              whiskerprops = dict(color="black"), flierprops = dict(markerfacecolor= "red"))

# Add title and axis labels
data.boxplot(column = "broadband_access_pct", by= "county_categorization", boxprops = dict(color = "red"), medianprops = dict(color="red"),
             whiskerprops = dict(color="black"), flierprops = dict(markerfacecolor= "red"))
plt.title("Broadband Access by County Categorization") # adds title
plt.suptitle("") # gets rid of default title
plt.xlabel("County Categorization") # adds x-label
plt.ylabel("Broadband Access") # adds y-label
# Out:
# Text(0, 0.5, 'Broadband Access')

# %%
# Histogram
## Shows distribution of values within variable
## The chart uses one variable, which should be numerical

# Create histogram for entire dataset
# data.hist()

# Change size of histogram by using figsize argument
# data.hist(figsize=(10,10))

# Change layout of rows and columns of charts
# data.hist(layout=(2,3), figsize=(10,6))

# Change color
# data.hist(color = "g", figsize=(10,10)) # can add color using the "color" argument
# data.hist(color = "darkseagreen", figsize=(10,10)) # there is also a list of named colors for matplotlib

# https://matplotlib.org/stable/users/explain/colors/colors.html#colors-def gives more info on colors for matplotlib

# Change number of bins
# data.hist(color = "darkseagreen", figsize=(10,10), bins = 20)

# Create histogram of just one variable
# data.broadband_access_pct.hist(color = "darkseagreen", bins = 30)
# plt.title("Distribution of Broadband Access")
# plt.xlabel("Broadband Access")

# Outline histogram bars
data.broadband_access_pct.hist(color = "darkseagreen", bins = 30, edgecolor = "black")
plt.title("Distribution of Broadband Access")
plt.xlabel("Broadband Access")
# Out:
# Text(0.5, 0, 'Broadband Access')

# %%
# Charts to look at relationships between variables

# %%
# Scatterplots
## Shows relationships between two variables
## Requires two numerical variables


# Create a scatterplot
# data.plot.scatter(x="broadband_access_pct", y="premature_births_pct")

# Change color
# data.plot.scatter(x="broadband_access_pct", y="premature_births_pct", color = "darkseagreen")

# Change color by another variable
# data.plot.scatter(x="broadband_access_pct", y="premature_births_pct", c="low_birthweight_births_pct", cmap = "viridis") # cmap is color map
# data.plot.scatter(x="broadband_access_pct", y="premature_births_pct", color = "darkseagreen", edgecolor="black")


# Change size
# data.plot.scatter(x="broadband_access_pct", y="premature_births_pct", s=data["low_birthweight_births_pct"]*7)

# Add title and axis labels
data.plot.scatter(x="broadband_access_pct", y="premature_births_pct", color = "darkseagreen", edgecolor="black", s=data["low_birthweight_births_pct"]*7)
plt.title("Broadband Access vs. Premature Births")
plt.xlabel("Broadband Access")
plt.ylabel("Premature Births")
# Out:
# Text(0, 0.5, 'Premature Births')

# %%
## Comparing different categories

# %%
data["maternity_care_deserts_value"].unique()
# Out:
# array(['Maternity Care Desert', 'Full Access', 'Low Access',
#        'Moderate Access'], dtype=object)

# %%
# Bar Charts
# Used to compare quantities across different categories
# Requires one categorical variable


# Create bar chart
# data.plot.bar(x="county_categorization")
# data.groupby("county_categorization")["broadband_access_pct"].mean().plot(kind="bar") # use groupby to aggregate data before plotting

# Sort bar values
# data.groupby("county_categorization")["broadband_access_pct"].mean().sort_values().plot(kind="bar") # use groupby to aggregate data before plotting
# data.groupby("county_categorization")["broadband_access_pct"].mean().sort_values(ascending=False).plot(kind="bar") # use groupby to aggregate data before plotting


# Change color
# data.groupby("county_categorization")["broadband_access_pct"].mean().plot(kind="bar", color = "darkseagreen")
# data.groupby("county_categorization")["broadband_access_pct"].mean().plot(kind="bar")

# Create grouped bar chart
# data.pivot_table(index = "maternity_care_deserts_value",columns = "county_categorization", values = "broadband_access_pct").plot(kind="bar")
# colors = ["coral", "crimson", "rosybrown", "chocolate"]
# data.pivot_table(index = "maternity_care_deserts_value",columns = "county_categorization", values = "broadband_access_pct").plot(kind="bar", color = colors)

# Add title and axis labels
# data.pivot_table(index = "maternity_care_deserts_value",columns = "county_categorization", values = "broadband_access_pct").plot(kind="bar")
# plt.title("Broadband Access by County Categorization")
# plt.xlabel("County Categorization")
# plt.ylabel("Broadband Access")
# Out:
# <Axes: xlabel='county_categorization'>

# %%
# Exploring the composition of a variable

# Stacked Bar Chart
# data.groupby(["county_categorization", "maternity_care_deserts_value"])["broadband_access_pct"].mean().unstack().plot(kind="bar", stacked=True)

# Pie Chart
data.groupby(['county_categorization'])["broadband_access_pct"].mean().plot.pie(figsize=(5, 5))
# Out:
# <Axes: ylabel='broadband_access_pct'>

# %%
# Object-Oriented Plotting

# Create visualiztions by adding charts, or axis, to a figure

# Figure - a container that contains all the objects of your plot, like the axes, graphics, text, and labels
# Axis - a chart that you add within your figure

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# creating a basic plot ---

# create figure and axis one at a time
fig = plt.figure() # creates figure object
ax = fig.add_subplot() # creates chart/axis using the figure object

# %%
# create figure and axis at same time

fig, ax = plt.subplots() # creates figure and axis object

# %%
# Adding plots

# %%
# Creating a plot using a list
fig, ax = plt.subplots()
lst = [3,4,5,10]
ax.plot(lst)

# %%
fig, ax = plt.subplots()
new_array = np.array([3,4,5,10])
ax.plot(new_array)

# %%
# Adding plots using dataframes

# Matplotlib uses the index as the x-axis and plots each column as a separate series by default

# We can use groupby() to aggregate data for plotting
county_df = data.groupby("county_categorization")["broadband_access_pct"].mean().reset_index()
county_df.head()

maternity_deserts_df = data.groupby("maternity_care_deserts_value")["broadband_access_pct"].mean().reset_index()
maternity_deserts_df.head()
# Out:
#   maternity_care_deserts_value  broadband_access_pct
# 0                  Full Access             83.304225
# 1                   Low Access             82.063636
# 2        Maternity Care Desert             57.779630
# 3              Moderate Access             65.200000

# %%
# Create plot using dataframe

# fig, ax = plt.subplots()  # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"]) # Add dataframe x and y axis into bar() function

# Add grid
# fig, ax = plt.subplots()  # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"])
# ax.grid(True) # add grid

# Change color of all bars
# fig, ax = plt.subplots()  # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")

# Change color of specific bar(s)
# fig, ax = plt.subplots()  # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color=["Grey", "Grey", "Grey", "Red"])


# Add title and subtitle

# fig, ax = plt.subplots() # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health") # figure-level title
# ax.set_title("Broadband Access by County Categorization") # chart-level title

# Add axis labels

# fig, ax = plt.subplots() # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health") # figure-level title
# ax.set_title("Broadband Access by County Categorization") # chart-level title
# ax.set_xlabel("County Categorization") # x-axis label
# ax.set_ylabel("Broadband Access (%)") # y-axis label

# Change font size
# fig, ax = plt.subplots() # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label


# Change axis limits
# fig, ax = plt.subplots() # create figure and axis
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 120) # modify axis limits

# Change figure size
# fig, ax = plt.subplots(figsize = (8,7)) # create figure and axis and change figure size
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 120) # modify axis limits

# Change axis ticks
# fig, ax = plt.subplots(figsize = (8,7)) # create figure and axis and change figure size
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 100) # modify axis limits
# ax.set_yticks([0, 60, 100]) # modify axis ticks
# plt.show()

# Add minor ticks
# fig, ax = plt.subplots(figsize = (8,7)) # create figure and axis and change figure size
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 100) # modify axis limits
# ax.set_yticks([0, 60, 100]) # modify axis ticks
# ax.minorticks_on() # add minor ticks
# ax.tick_params(axis='y', which='minor', length=4, color='black') # modify minor ticks
# plt.show()

# Add horizontal line
# fig, ax = plt.subplots(figsize = (8,7)) # create figure and axis and change figure size
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 100) # modify axis limits
# ax.set_yticks([0, 60, 100]) # modify axis ticks
# ax.minorticks_on() # add minor ticks
# ax.tick_params(axis='y', which='minor', length=4, color='black') # modify minor ticks
# ax.axhline(np.mean(data["broadband_access_pct"]), color="black")
# plt.show()

# Change line style
# fig, ax = plt.subplots(figsize = (8,7)) # create figure and axis and change figure size
# ax.bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=16) # figure-level title
# ax.set_title("Broadband Access by County Categorization", fontsize=14) # chart-level title
# ax.set_xlabel("County Categorization", fontsize=10) # x-axis label
# ax.set_ylabel("Broadband Access (%)", fontsize=10) # y-axis label
# ax.set_ylim(0, 100) # modify axis limits
# ax.set_yticks([0, 60, 100]) # modify axis ticks
# ax.minorticks_on() # add minor ticks
# ax.tick_params(axis='y', which='minor', length=4, color='black') # modify minor ticks
# ax.axhline(np.mean(data["broadband_access_pct"]), color="black", ls=":")
# plt.show()

# Adding a legend
# Out:
# <BarContainer object of 4 artists>

# %%
# Creating subplots


# fig, axs = plt.subplots(2,figsize=(6,4)) # create figure and axis, argument creates number of rows for figure
# axs[0].bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# axs[1].bar(maternity_deserts_df["maternity_care_deserts_value"], maternity_deserts_df["broadband_access_pct"], color="darkseagreen")

# Add more space between subplots
# fig, axs = plt.subplots(2,figsize=(6,4)) # create figure and axis, argument creates number of rows for figure
# axs[0].bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# axs[1].bar(maternity_deserts_df["maternity_care_deserts_value"], maternity_deserts_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=10) # figure-level title
# axs[0].set_title("Broadband Access by County Categorization", fontsize=9) # chart-level title
# axs[0].set_xlabel("County Categorization", fontsize=8) # x-axis label
# axs[0].set_ylabel("Broadband Access (%)", fontsize=8) # y-axis label
# axs[1].set_title("Maternity Care Categories by County Categorization", fontsize=9) # chart-level title
# axs[1].set_xlabel("Maternity Care Deserts", fontsize=8) # x-axis label
# axs[1].set_ylabel("Broadband Access (%)", fontsize=8) # y-axis label
# fig.subplots_adjust(top= 0.85, hspace = 0.7) # adjust placement of subplots on figure

# Add titles to figure and charts
# fig, axs = plt.subplots(2,figsize=(5,4)) # create figure and axis, argument creates number of rows for figure
# axs[0].bar(county_df["county_categorization"], county_df["broadband_access_pct"], color="darkseagreen")
# axs[1].bar(maternity_deserts_df["maternity_care_deserts_value"], maternity_deserts_df["broadband_access_pct"], color="darkseagreen")
# fig.suptitle("Exploring Maternal Health", fontsize=10) # figure-level title
# axs[0].set_title("Broadband Access by County Categorization", fontsize=9) # chart-level title
# axs[0].set_xlabel("County Categorization", fontsize=8) # x-axis label
# axs[0].set_ylabel("Broadband Access (%)", fontsize=8) # y-axis label
# axs[1].set_title("Maternity Care Categories by County Categorization", fontsize=9) # chart-level title
# axs[1].set_xlabel("Maternity Care Deserts", fontsize=8) # x-axis label
# axs[1].set_ylabel("Broadband Access (%)", fontsize=8) # y-axis label
# fig.subplots_adjust(top= 0.85, hspace = 0.7) # adjust placement of subplots on figure
# axs[0].tick_params(axis="x", labelsize=6)
# axs[1].tick_params(axis="x", labelsize=6)

# %%
# Seaborn
# Seaborn is a popular data visualization library built using the Matplotlib API

# %%
# bar charts
# Create bar chart
#sns.barplot(x="county_categorization", y="broadband_access_pct", data=data)

# Create bar chart using mean as aggregation method
# sns.barplot(x="county_categorization", y="broadband_access_pct", data=data, estimator="mean")

# Add title and labels
# sns.barplot(x="county_categorization", y="broadband_access_pct", data=data, estimator="mean")
# plt.title("Broadband Access vs. Maternity Care Desert")
# plt.xlabel("Maternity Care Deserts")
# plt.ylabel("Broadband Access (%)")

# Change color
# sns.barplot(x="county_categorization", y="broadband_access_pct", data=data, estimator="mean", color="darkseagreen")
# plt.title("Broadband Access vs. Maternity Care Desert")
# plt.xlabel("Maternity Care Deserts")
# plt.ylabel("Broadband Access (%)")

# Create subplots
fig, axs = plt.subplots(2, figsize=(6, 4))
sns.barplot(x="county_categorization", y="broadband_access_pct", data=county_df, estimator="mean", color="darkseagreen", ax=axs[0])
axs[0].set_title("Broadband Access vs. Maternity Care Desert")

sns.barplot(x='maternity_care_deserts_value', y='broadband_access_pct', data=maternity_deserts_df, color="darkseagreen", ax=axs[1])
axs[1].set_title('Maternity Care Categories by County Categorization')
# Out:
# Text(0.5, 1.0, 'Maternity Care Categories by County Categorization')

# %%
# scatterplots

# Create a scatterplot
# sns.scatterplot(x="low_birthweight_births_pct",
#                 y= "broadband_access_pct",
#                 data = data)

# Add color based on variable
# sns.scatterplot(x="low_birthweight_births_pct",
#                 y= "broadband_access_pct",
#                 data = data,
#                 hue="county_categorization")
# Out:
# <Axes: xlabel='low_birthweight_births_pct', ylabel='broadband_access_pct'>
